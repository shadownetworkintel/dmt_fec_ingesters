# %%
# %load_ext sql

# %sql postgresql://postgres:EMvAYOrD%23BYU8y@localhost/political_finance_data
# %config SqlMagic.style = 'PLAIN_COLUMNS'
# %config SqlMagic.autopandas = True
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
# select * from schedule_a_contributions LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/political_finance_data
# 5 rows affected.
#   amendment_indicator amendment_indicator_desc back_reference_schedule_name  \
# 0                   A                      ADD                         None
# 1                   A                      ADD                         None
# 2                   A                      ADD                         None
# 3                   A                      ADD                         None
# 4                   A                      ADD                         None
#
#   back_reference_transaction_id candidate_first_name candidate_id  \
# 0                          None                 None         None
# 1                          None                 None         None
# 2                          None                 None         None
# 3                          None                 None         None
# 4                          None                 None         None
#
# ...

# %%
# %%sql
# SELECT * FROM committees LIMIT 5;
# Out:
#  * postgresql://postgres:***@localhost/political_finance_data
# 5 rows affected.
#   committee_id                                               name designation  \
# 0    C00000000                                UFWA COPE COMMITTEE           U
# 1    C00000018  IRONWORKERS LOCAL UNION NO. 25 POLITICAL EDUCA...           U
# 2    C00000026  INTERNATIONAL CHIROPRACTORS ASSOCIATION POLITI...           U
# 3    C00000042  ILLINOIS TOOL WORKS INC. FOR BETTER GOVERNMENT...           B
# 4    C00000059                 HALLMARK CARDS, INC. PAC (HALLPAC)           B
#
#           designation_full committee_type committee_type_full  \
# 0             Unauthorized              Q     PAC - Qualified
# 1             Unauthorized              Q     PAC - Qualified
# 2             Unauthorized              Q     PAC - Qualified
# 3  Lobbyist/Registrant PAC              Q     PAC - Qualified
# 4  Lobbyist/Registrant PAC              Q     PAC - Qualified
#
# ...

# %%
results = %sql SELECT contributor_name, contribution_receipt_amount FROM schedule_a_contributions LIMIT 10;
print(results)
# Out:
#  * postgresql://postgres:***@localhost/political_finance_data
# 10 rows affected.
#     contributor_name contribution_receipt_amount
# 0     RAJA, PRABURAM                      288.45
# 1   PONNEKANTI, HARI                      300.00
# 2        PON, JOSEPH                      300.00
# 3    PATIBANDLA, NAG                      105.00
# 4  NALAMASU, OMKARAM                      288.45
# 5       MURPHY, PAUL                      120.00
# 6   MARRUFO, CHRISTI                      150.00
# 7        KANIA, JOHN                      115.50
# 8      JAYARAM, HARI                      300.00
# 9     HANSON, THOMAS                      115.38
